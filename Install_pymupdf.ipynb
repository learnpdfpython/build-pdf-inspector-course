# %% [markdown]
# <a href="https://colab.research.google.com/github/learnpdfpython/build-pdf-inspector-course/blob/main/Install_pymupdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q -U pymupdf

# %%
import pymupdf
print(pymupdf.__version__)
# Out:
# 1.28.0
